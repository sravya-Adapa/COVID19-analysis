# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')

# %%
df
# Out:
#       sno                                state_name  ...  total  state_code
# 0       2               Andaman and Nicobar Islands  ...                 35
# 1       1                            Andhra Pradesh  ...      9          28
# 2       3                         Arunachal Pradesh  ...                 12
# 3       4                                     Assam  ...     12          18
# 4       5                                     Bihar  ...                 10
# 5       6                                Chandigarh  ...      2          04
# 6       7                              Chhattisgarh  ...      9          22
# 7       8  Dadra and Nagar Haveli and Daman and Diu  ...                 26
# 8      10                                     Delhi  ...     14          07
# 9      11                                       Goa  ...      7          30
# 10     12                                   Gujarat  ...     19          24
# 11     13                                   Haryana  ...      9          06
# 12     14                          Himachal Pradesh  ...     11          02
# 13     15                         Jammu and Kashmir  ...      9          01
# 14     16                                 Jharkhand  ...      1          20
# 15     17                                 Karnataka  ...     47          29
# 16     18                                 Kerala***  ...    515          32
# 17     19                                    Ladakh  ...                 37
# 18     20                               Lakshadweep  ...                 31
# 19     21                            Madhya Pradesh  ...      6          23
# 20     22                               Maharashtra  ...     66          27
# 21     23                                   Manipur  ...      4          14
# 22     24                                 Meghalaya  ...      4          17
# 23     25                                   Mizoram  ...      2          15
# 24     26                                  Nagaland  ...      2          13
# 25     27                                    Odisha  ...     23          21
# 26     28                                Puducherry  ...      1          34
# 27     29                                    Punjab  ...     28          03
# 28     30                                 Rajasthan  ...      7          08
# 29     31                                    Sikkim  ...      1          11
# 30     32                                Tamil Nadu  ...     26          33
# 31     34                                 Telangana  ...      1          36
# 32     33                                   Tripura  ...      2          16
# 33     35                               Uttarakhand  ...      9          05
# 34     36                             Uttar Pradesh  ...     15          09
# 35     37                               West Bengal  ...     34          19
# 36  11111                                            ...    895
#
# [37 rows x 13 columns]

# %%
df.shape
# Out:
# (37, 13)

# %%
df.isnull().sum()
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     object
# dtypes: int64(9), object(4)
# memory usage: 3.9+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       sno                                state_name  ...  total  state_code
# 0       2               Andaman and Nicobar Islands  ...                 35
# 1       1                            Andhra Pradesh  ...      9          28
# 2       3                         Arunachal Pradesh  ...                 12
# 3       4                                     Assam  ...     12          18
# 4       5                                     Bihar  ...                 10
# 5       6                                Chandigarh  ...      2          04
# 6       7                              Chhattisgarh  ...      9          22
# 7       8  Dadra and Nagar Haveli and Daman and Diu  ...                 26
# 8      10                                     Delhi  ...     14          07
# 9      11                                       Goa  ...      7          30
# 10     12                                   Gujarat  ...     19          24
# 11     13                                   Haryana  ...      9          06
# 12     14                          Himachal Pradesh  ...     11          02
# 13     15                         Jammu and Kashmir  ...      9          01
# 14     16                                 Jharkhand  ...      1          20
# 15     17                                 Karnataka  ...     47          29
# 16     18                                 Kerala***  ...    515          32
# 17     19                                    Ladakh  ...                 37
# 18     20                               Lakshadweep  ...                 31
# 19     21                            Madhya Pradesh  ...      6          23
# 20     22                               Maharashtra  ...     66          27
# 21     23                                   Manipur  ...      4          14
# 22     24                                 Meghalaya  ...      4          17
# 23     25                                   Mizoram  ...      2          15
# 24     26                                  Nagaland  ...      2          13
# 25     27                                    Odisha  ...     23          21
# 26     28                                Puducherry  ...      1          34
# 27     29                                    Punjab  ...     28          03
# 28     30                                 Rajasthan  ...      7          08
# 29     31                                    Sikkim  ...      1          11
# 30     32                                Tamil Nadu  ...     26          33
# 31     34                                 Telangana  ...      1          36
# 32     33                                   Tripura  ...      2          16
# 33     35                               Uttarakhand  ...      9          05
# 34     36                             Uttar Pradesh  ...     15          09
# 35     37                               West Bengal  ...     34          19
# 36  11111                                            ...    895
#
# [37 rows x 13 columns]>

# %%
df.describe()
# Out:
#                 sno        active  ...     new_cured      new_death
# count     37.000000  3.700000e+01  ...  3.700000e+01      37.000000
# mean     319.054054  6.621681e+04  ...  2.197849e+06   27182.378378
# std     1823.499245  2.062740e+05  ...  6.701932e+06   84263.001721
# min        1.000000  9.800000e+01  ...  9.587000e+03       4.000000
# 25%       11.000000  1.907000e+03  ...  9.899700e+04    1139.000000
# 50%       20.000000  1.231600e+04  ...  7.051180e+05    6561.000000
# 75%       29.000000  3.251400e+04  ...  1.237976e+06   14664.000000
# max    11111.000000  1.225011e+06  ...  4.066020e+07  502874.000000
#
# [8 rows x 9 columns]

# %%
df.iloc
# Out:
#    sno                                state_name  ...  total  state_code
# 0    2               Andaman and Nicobar Islands  ...                 35
# 1    1                            Andhra Pradesh  ...      9          28
# 2    3                         Arunachal Pradesh  ...                 12
# 3    4                                     Assam  ...     12          18
# 4    5                                     Bihar  ...                 10
# 5    6                                Chandigarh  ...      2          04
# 6    7                              Chhattisgarh  ...      9          22
# 7    8  Dadra and Nagar Haveli and Daman and Diu  ...                 26
# 8   10                                     Delhi  ...     14          07
# 9   11                                       Goa  ...      7          30
#
# [10 rows x 13 columns]

# %%
df.keys()
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# Out:
# sno                 37
# state_name          37
# active              37
# positive            37
# cured               37
# death               37
# new_active          37
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total               20
# state_code          37
# dtype: int64

# %%
df.tail()
# Out:
#       sno     state_name   active  ...  death_reconsille  total  state_code
# 32     33        Tripura      887  ...                        2          16
# 33     35    Uttarakhand    17280  ...                        9          05
# 34     36  Uttar Pradesh    32514  ...                       15          09
# 35     37    West Bengal    19276  ...                       34          19
# 36  11111                 1225011  ...               378    895
#
# [5 rows x 13 columns]

# %%
df = df.iloc[:36]

# %%
df
# Out:
#     sno                                state_name  ...  total  state_code
# 0     2               Andaman and Nicobar Islands  ...                 35
# 1     1                            Andhra Pradesh  ...      9          28
# 2     3                         Arunachal Pradesh  ...                 12
# 3     4                                     Assam  ...     12          18
# 4     5                                     Bihar  ...                 10
# 5     6                                Chandigarh  ...      2          04
# 6     7                              Chhattisgarh  ...      9          22
# 7     8  Dadra and Nagar Haveli and Daman and Diu  ...                 26
# 8    10                                     Delhi  ...     14          07
# 9    11                                       Goa  ...      7          30
# 10   12                                   Gujarat  ...     19          24
# 11   13                                   Haryana  ...      9          06
# 12   14                          Himachal Pradesh  ...     11          02
# 13   15                         Jammu and Kashmir  ...      9          01
# 14   16                                 Jharkhand  ...      1          20
# 15   17                                 Karnataka  ...     47          29
# 16   18                                 Kerala***  ...    515          32
# 17   19                                    Ladakh  ...                 37
# 18   20                               Lakshadweep  ...                 31
# 19   21                            Madhya Pradesh  ...      6          23
# 20   22                               Maharashtra  ...     66          27
# 21   23                                   Manipur  ...      4          14
# 22   24                                 Meghalaya  ...      4          17
# 23   25                                   Mizoram  ...      2          15
# 24   26                                  Nagaland  ...      2          13
# 25   27                                    Odisha  ...     23          21
# 26   28                                Puducherry  ...      1          34
# 27   29                                    Punjab  ...     28          03
# 28   30                                 Rajasthan  ...      7          08
# 29   31                                    Sikkim  ...      1          11
# 30   32                                Tamil Nadu  ...     26          33
# 31   34                                 Telangana  ...      1          36
# 32   33                                   Tripura  ...      2          16
# 33   35                               Uttarakhand  ...      9          05
# 34   36                             Uttar Pradesh  ...     15          09
# 35   37                               West Bengal  ...     34          19
#
# [36 rows x 13 columns]

# %%
df.head()
# Out:
#    sno                   state_name  active  ...  death_reconsille  total  state_code
# 0    2  Andaman and Nicobar Islands     214  ...                                   35
# 1    1               Andhra Pradesh   78746  ...                        9          28
# 2    3            Arunachal Pradesh    1800  ...                                   12
# 3    4                        Assam   11928  ...                       12          18
# 4    5                        Bihar    2917  ...                                   10
#
# [5 rows x 13 columns]

# %%
df['active'].sum(axis=0)
# Out:
# 1225011

# %%
df['positive'].sum(axis=0)
# Out:
# 42188138

# %%
df['cured'].sum(axis=0)
# Out:
# 40461148

# %%
df['death'].sum(axis=0)
# Out:
# 502357

# %%
df['new_active'].sum(axis=0)
# Out:
# 1108938

# %%
df['new_positive'].sum(axis=0)
# Out:
# 42272014

# %%
df['new_cured'].sum(axis=0)
# Out:
# 40660202

# %%
df['new_death'].sum(axis=0)
# Out:
# 502874

# %%
sns.pairplot(data=df)

# %%
cases_df = df.sum()
cases_df
# Out:
# sno                                                               694
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                        1225011
# positive                                                     42188138
# cured                                                        40461148
# death                                                          502357
# new_active                                                    1108938
# new_positive                                                 42272014
# new_cured                                                    40660202
# new_death                                                      502874
# death_reconsille                                                  378
# total                     9122914719911914751566644222312871261291534
# state_code          3528121810042226073024060201202932373123271417...
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace = True)

# %%
cases_df
# Out:
# active                                                  1225011
# positive                                               42188138
# cured                                                  40461148
# death                                                    502357
# new_active                                              1108938
# new_positive                                           42272014
# new_cured                                              40660202
# new_death                                                502874
# death_reconsille                                            378
# total               9122914719911914751566644222312871261291534
# dtype: object

# %%
my_data = ['1225011','42188138','40461148','502357']
my_labels = 'Active', 'Positive', 'Cured', 'Death'
my_explode = (0,0,0,1.5)
my_colors = ['red','blue','green','black']
fig1, ax1 = plt.subplots(figsize=(13,8))
plt.pie(my_data,labels = my_labels,autopct = '%1.1f%%', startangle = 15, shadow = True, colors = my_colors, explode = my_explode)
plt.axis('equal')
plt.show()

# %%
my_data = ['1108938', ' 42272014','40660202','502874']
my_labels = 'New Active', 'New Positive', 'New Cured', 'New Death'
my_explode = (0,0,0,1.5)
my_colors = ['red','blue','green','black']
fig1, ax1 = plt.subplots(figsize=(13,8))
plt.pie(my_data,labels = my_labels,autopct = '%1.1f%%', startangle = 15, shadow = True, colors = my_colors, explode = my_explode)
plt.axis('equal')
plt.show()

# %%
my_data = ['1225011','42188138','40461148','502357','1108938', ' 42272014','40660202','502874']
my_labels = 'Active', 'Positive', 'Cured', 'Death' 'New Active', 'New Positive', 'New Cured', 'New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalomond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13,8))
plt.pie(my_data, labels = my_labels,autopct = '%1.1f%%', startangle = 15, shadow = True, colors = my_colors, explode = my_explode)
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-87779204049b> in <module>()
#       4 my_colors = ['gray','navajowhite','blanchedalomond','grey','lightblue','papayawhip','moccasin','lightpink']
#       5 fig1, ax1 = plt.subplots(figsize=(13,8))
# ----> 6 plt.pie(my_data, labels = my_labels,autopct = '%1.1f%%', startangle = 15, shadow = True, colors = my_colors, explode = my_explode)
#       7 plt.axis('equal')
#       8 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2927             explode = [0] * len(x)
#    2928         if len(x) != len(labels):
# -> 2929             raise ValueError("'label' must be of length 'x'")
#    2930         if len(x) != len(explode):
#    2931             raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'

# %%
plt.rcParams['figure.figsize'] = (13,8)

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='blue')
plt.show()

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(x='state_name',y='active',color='teal',data = df,)

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(x='state_name',y='positive',color='teal',data = df,)

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(x='state_name',y='cured',color='teal',data = df,)

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(x='state_name',y='new_active',color='teal',data = df,)

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(x='state_name',y='new_positive',color='teal',data = df,)

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(x='state_name',y='new_cured',color='teal',data = df,)

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(x='state_name',y='death',color='teal',data = df,)

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-2a08b874c8c2> in <module>()
# ----> 1 df.drop(['sno','state_code'],axis=1,inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['sno' 'state_code'] not found in axis"

# %%
df.head(5)
# Out:
#                     state_name  active  ...  death_reconsille  total
# 0  Andaman and Nicobar Islands     214  ...
# 1               Andhra Pradesh   78746  ...                        9
# 2            Arunachal Pradesh    1800  ...
# 3                        Assam   11928  ...                       12
# 4                        Bihar    2917  ...
#
# [5 rows x 11 columns]

# %%
df = df.set_index('state_name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-6524ca7a05de> in <module>()
# ----> 1 df = df.set_index('state_name')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['state_name'] are in the columns"

# %%
df.head(5)
# Out:
#                              active  positive  ...  death_reconsille  total
# state_name                                     ...
# Andaman and Nicobar Islands     214      9896  ...
# Andhra Pradesh                78746   2300765  ...                        9
# Arunachal Pradesh              1800     63421  ...
# Assam                         11928    721124  ...                       12
# Bihar                          2917    827017  ...
#
# [5 rows x 10 columns]

# %%
df.plot.barh(stacked = True,figsize = (13,8))

# %%
df1 = df[['cured','death']]
df1.plot.barh(color={"cured":"green","death":"red"},figsize = (13,8))

# %%
df2 = df[['positive','death']]
df2.plot.barh(color={"positive":"lightgreen","death":"brown"},figsize=(13,8))

# %%
df2 = df[['death','cured']]
df2.plot.barh(color={"death":"red","cured":"green"},figsize=(13,8))

# %%
df2 = df[['active','death']]
df2.plot.barh(color={"active":"brown","death":"orange"},figsize=(13,8))
